# %%
import numpy as np

# %%
s1 = np.array([
    [1,0],
    [6/9,1]
])

s2 = np.array([
    [1,12],
    [0,1]
])

bottleneck = np.array([
    [9,0],
    [0,6/9]
])

s1@s2@bottleneck
# Out:
# array([[9., 8.],
#        [6., 6.]])
