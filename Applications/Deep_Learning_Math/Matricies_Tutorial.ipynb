# %%
# %load_ext autoreload
# %autoreload 2

# %%
"""
Purpose: To demonstrate intuitive tutorials
on how matrices math operations work
"""
# Out:
# '\nPurpose: To demonstrate intuitive tutorials\non how matrices math operations work\n'

# %%
from os import sys
from pathlib import Path
base_path = Path("/content/drive/MyDrive/Deep_Learning/torch_tools/torch_tools")
sys.path.append(str(base_path ))
sys.path.append(str(base_path / Path("linalg")))

# %%
import numpy as np

# %%
import matrix
import vector as vec

# %% [markdown]
# # Part 0: Dummy Data

# %%
M = np.array([
    [1,4,6,9],
    [10,20,-5,6],
    [3,8,9, 10],
])

x = np.array([7,8,9,10])

# %% [markdown]
# # Part 1: Intuitive Mx Magnitude Calculation from individual magnitudes and cross terms

# %%
matrix.intuitive_matrix_product_magn_from_individual_and_cross_terms(
    M,x,verbose = True
)
# Out:
# magn = 405.30235627245
# magn_check = 405.30235627245
# 405.30235627245
